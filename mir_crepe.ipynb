# %%
pip install -r requirements.txt

# %%
# !pip install .

# %%
pip install librosa

# %%
pip install tensorflow

# %%
pip install tqdm

# %%
import os
os.chdir("..")

# %% [markdown]
# ## Crepe

# %% [markdown]
# ## generate h5 file for audios

# %%
import crepe
import librosa
import numpy as np
import os
import h5py
from tqdm import tqdm

# Load directories
audio_dir = "/Volumes/T7/mini_MedleyDB_pitch/audio"
output_dir = "/Volumes/T7/mini_MedleyDB_pitch/processed_pitch_h5"
os.makedirs(output_dir, exist_ok=True)

# Path for the HDF5 file
h5_file_path = os.path.join(output_dir, "processed_pitches.h5")

# Create an HDF5 file
with h5py.File(h5_file_path, "w") as h5_file:
    # Process each audio file
    for audio_path in tqdm(audio_files, desc="Processing audio files"):
        try:
            print(f"Processing: {audio_path}")
            
            # Load audio
            audio, sr = librosa.load(audio_path, sr=16000, mono=True)

            # Run pitch detection using CREPE
            time, frequency, confidence, _ = crepe.predict(audio, sr, model_capacity='full', viterbi=True)

            # Store results in HDF5 file
            group_name = os.path.basename(audio_path).replace('.wav', '')
            group = h5_file.create_group(group_name)
            group.create_dataset("time", data=time)
            group.create_dataset("frequency", data=frequency)
            group.create_dataset("confidence", data=confidence)

            print(f"Saved pitch data to HDF5 group: {group_name}")

        except Exception as e:
            error_log_path = os.path.join(output_dir, "error_log.txt")
            with open(error_log_path, "a") as error_log:
                error_log.write(f"Error processing {audio_path}: {e}\n")
            print(f"Error processing {audio_path}: {e}")
# Out:
# Processing audio files:   0%|          | 0/24 [00:00<?, ?it/s]
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/BigTroubles_Phantom_STEM_04.wav
# 460/460 [==============================] - 17s 38ms/step
# Processing audio files:   4%|▍         | 1/24 [00:20<07:45, 20.25s/it]
# Saved pitch data to HDF5 group: BigTroubles_Phantom_STEM_04
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Britpop_STEM_08.wav
# 115/115 [==============================] - 5s 40ms/step
# Processing audio files:   8%|▊         | 2/24 [00:25<04:13, 11.51s/it]
# Saved pitch data to HDF5 group: MusicDelta_Britpop_STEM_08
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_Stella_STEM_07.wav
# 612/612 [==============================] - 25s 41ms/step
# Processing audio files:  12%|█▎        | 3/24 [00:54<06:50, 19.53s/it]
# Saved pitch data to HDF5 group: ClaraBerryAndWooldog_Stella_STEM_07
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/PortStWillow_StayEven_STEM_08.wav
# 991/991 [==============================] - 41s 41ms/step
# Processing audio files:  17%|█▋        | 4/24 [01:41<10:05, 30.28s/it]
# Saved pitch data to HDF5 group: PortStWillow_StayEven_STEM_08
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_80sRock_STEM_04.wav
# 116/116 [==============================] - 5s 39ms/step
# Processing audio files:  21%|██        | 5/24 [01:46<06:44, 21.27s/it]
# Saved pitch data to HDF5 group: MusicDelta_80sRock_STEM_04
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/StrandOfOaks_Spacestation_STEM_04.wav
# 763/763 [==============================] - 31s 40ms/step
# Processing audio files:  25%|██▌       | 6/24 [02:22<07:49, 26.09s/it]
# Saved pitch data to HDF5 group: StrandOfOaks_Spacestation_STEM_04
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/TheScarletBrand_LesFleursDuMal_STEM_08.wav
# 949/949 [==============================] - 42s 44ms/step
# Processing audio files:  29%|██▉       | 7/24 [03:11<09:30, 33.55s/it]
# Saved pitch data to HDF5 group: TheScarletBrand_LesFleursDuMal_STEM_08
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.wav
# 549/549 [==============================] - 23s 42ms/step
# Processing audio files:  33%|███▎      | 8/24 [03:37<08:21, 31.34s/it]
# Saved pitch data to HDF5 group: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/Creepoid_OldTree_STEM_07.wav
# 945/945 [==============================] - 42s 45ms/step
# Processing audio files:  38%|███▊      | 9/24 [04:26<09:09, 36.65s/it]
# Saved pitch data to HDF5 group: Creepoid_OldTree_STEM_07
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_AirTraffic_STEM_08.wav
# 543/543 [==============================] - 25s 46ms/step
# Processing audio files:  42%|████▏     | 10/24 [04:54<07:58, 34.17s/it]
# Saved pitch data to HDF5 group: ClaraBerryAndWooldog_AirTraffic_STEM_08
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/CelestialShore_DieForUs_STEM_02.wav
# 871/871 [==============================] - 38s 43ms/step
# Processing audio files:  46%|████▌     | 11/24 [05:38<08:01, 37.04s/it]
# Saved pitch data to HDF5 group: CelestialShore_DieForUs_STEM_02
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/CelestialShore_DieForUs_STEM_01.wav
# 871/871 [==============================] - 40s 46ms/step
# Processing audio files:  50%|█████     | 12/24 [06:23<07:55, 39.60s/it]
# Saved pitch data to HDF5 group: CelestialShore_DieForUs_STEM_01
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/SecretMountains_HighHorse_STEM_09.wav
# 1111/1111 [==============================] - 47s 43ms/step
# Processing audio files:  54%|█████▍    | 13/24 [07:17<08:04, 44.03s/it]
# Saved pitch data to HDF5 group: SecretMountains_HighHorse_STEM_09
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Disco_STEM_04.wav
# 390/390 [==============================] - 16s 41ms/step
# Processing audio files:  58%|█████▊    | 14/24 [07:37<06:05, 36.53s/it]
# Saved pitch data to HDF5 group: MusicDelta_Disco_STEM_04
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Beatles_STEM_08.wav
# 114/114 [==============================] - 4s 39ms/step
# Processing audio files:  62%|██████▎   | 15/24 [07:42<04:03, 27.08s/it]
# Saved pitch data to HDF5 group: MusicDelta_Beatles_STEM_08
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Gospel_STEM_06.wav
# 237/237 [==============================] - 10s 42ms/step
# Processing audio files:  67%|██████▋   | 16/24 [07:53<02:59, 22.41s/it]
# Saved pitch data to HDF5 group: MusicDelta_Gospel_STEM_06
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Country1_STEM_05.wav
# 109/109 [==============================] - 4s 40ms/step
# Processing audio files:  71%|███████   | 17/24 [07:58<02:00, 17.17s/it]
# Saved pitch data to HDF5 group: MusicDelta_Country1_STEM_05
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Country2_STEM_05.wav
# 55/55 [==============================] - 2s 40ms/step
# Processing audio files:  75%|███████▌  | 18/24 [08:01<01:16, 12.79s/it]
# Saved pitch data to HDF5 group: MusicDelta_Country2_STEM_05
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/BrandonWebster_YesSirICanFly_STEM_02.wav
# 312/312 [==============================] - 13s 40ms/step
# Processing audio files:  79%|███████▉  | 19/24 [08:15<01:06, 13.29s/it]
# Saved pitch data to HDF5 group: BrandonWebster_YesSirICanFly_STEM_02
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Reggae_STEM_04.wav
# 55/55 [==============================] - 2s 39ms/step
# Processing audio files:  83%|████████▎ | 20/24 [08:18<00:40, 10.05s/it]
# Saved pitch data to HDF5 group: MusicDelta_Reggae_STEM_04
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/FacesOnFilm_WaitingForGa_STEM_03.wav
# 806/806 [==============================] - 39s 48ms/step
# Processing audio files:  88%|████████▊ | 21/24 [09:02<01:00, 20.32s/it]
# Saved pitch data to HDF5 group: FacesOnFilm_WaitingForGa_STEM_03
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Britpop_STEM_07.wav
# 115/115 [==============================] - 6s 48ms/step
# Processing audio files:  92%|█████████▏| 22/24 [09:09<00:32, 16.16s/it]
# Saved pitch data to HDF5 group: MusicDelta_Britpop_STEM_07
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/TheSoSoGlos_Emergency_STEM_05.wav
# 522/522 [==============================] - 25s 48ms/step
# Processing audio files:  96%|█████████▌| 23/24 [09:37<00:19, 19.80s/it]
# Saved pitch data to HDF5 group: TheSoSoGlos_Emergency_STEM_05
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/NightPanther_Fire_STEM_07.wav
# 666/666 [==============================] - 31s 47ms/step
# Processing audio files: 100%|██████████| 24/24 [10:12<00:00, 25.53s/it]
# Saved pitch data to HDF5 group: NightPanther_Fire_STEM_07

# %% [markdown]
# ### Piano roll by Crepe

# %%
import crepe
import librosa
import numpy as np
import os
import h5py
from tqdm import tqdm

# %%
import matplotlib.pyplot as plt

# Path to your HDF5 file
h5_file_path = "/Volumes/T7/mini_MedleyDB_pitch/processed_pitch_h5/processed_pitches.h5"

# Load the HDF5 file
with h5py.File(h5_file_path, "r") as h5_file:
    # List all audio groups
    audio_groups = list(h5_file.keys())
    print(f"Available groups (audio files): {audio_groups}")
    
    # Select a group to analyze
    group_name = audio_groups[0]  # Change this index or name to analyze a specific group
    print(f"Analyzing group: {group_name}")

    # Load datasets
    time = h5_file[group_name]["time"][:]
    frequency = h5_file[group_name]["frequency"][:]
    confidence = h5_file[group_name]["confidence"][:]

    # Filter out low-confidence predictions (optional)
    confidence_threshold = 0.5
    filtered_time = time[confidence > confidence_threshold]
    filtered_frequency = frequency[confidence > confidence_threshold]
    filtered_confidence = confidence[confidence > confidence_threshold]

    # Print basic statistics
    print(f"Time range: {time.min()} to {time.max()} seconds")
    print(f"Frequency range: {frequency.min()} to {frequency.max()} Hz")
    print(f"Confidence range: {confidence.min()} to {confidence.max()}")

    # Plot frequency vs. time
    plt.figure(figsize=(12, 6))
    plt.scatter(filtered_time, filtered_frequency, c=filtered_confidence, cmap="viridis", s=10, label="Pitch")
    plt.colorbar(label="Confidence")
    plt.xlabel("Time (s)")
    plt.ylabel("Frequency (Hz)")
    plt.title(f"Pitch Contour for {group_name}")
    plt.grid()
    plt.legend()
    plt.show()

    # Histogram of confidence scores
    plt.figure(figsize=(8, 4))
    plt.hist(confidence, bins=50, alpha=0.7, label="Confidence")
    plt.axvline(confidence_threshold, color="red", linestyle="--", label="Threshold")
    plt.xlabel("Confidence")
    plt.ylabel("Count")
    plt.title("Confidence Distribution")
    plt.legend()
    plt.show()
# Out:
# Available groups (audio files): ['BigTroubles_Phantom_STEM_04', 'BrandonWebster_YesSirICanFly_STEM_02', 'CelestialShore_DieForUs_STEM_01', 'CelestialShore_DieForUs_STEM_02', 'ClaraBerryAndWooldog_AirTraffic_STEM_08', 'ClaraBerryAndWooldog_Stella_STEM_07', 'ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05', 'Creepoid_OldTree_STEM_07', 'FacesOnFilm_WaitingForGa_STEM_03', 'MusicDelta_80sRock_STEM_04', 'MusicDelta_Beatles_STEM_08', 'MusicDelta_Britpop_STEM_07', 'MusicDelta_Britpop_STEM_08', 'MusicDelta_Country1_STEM_05', 'MusicDelta_Country2_STEM_05', 'MusicDelta_Disco_STEM_04', 'MusicDelta_Gospel_STEM_06', 'MusicDelta_Reggae_STEM_04', 'NightPanther_Fire_STEM_07', 'PortStWillow_StayEven_STEM_08', 'SecretMountains_HighHorse_STEM_09', 'StrandOfOaks_Spacestation_STEM_04', 'TheScarletBrand_LesFleursDuMal_STEM_08', 'TheSoSoGlos_Emergency_STEM_05']
# Analyzing group: BigTroubles_Phantom_STEM_04
# Time range: 0.0 to 146.93 seconds
# Frequency range: 32.12943428857948 to 1792.6172948601588 Hz
# Confidence range: 0.024741102010011673 to 0.9323703646659851

# %%
pip install pretty_midi

# %%
import h5py
import numpy as np
import pretty_midi
import os

# Path to your HDF5 file
h5_file_path = "/Volumes/T7/mini_MedleyDB_pitch/processed_pitch_h5/processed_pitches.h5"
output_dir = "/Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe"
os.makedirs(output_dir, exist_ok=True)

# Parameters for piano roll
fs = 100  # Sampling frequency for time resolution (100 frames per second)
midi_min_pitch = 21  # Lowest MIDI note (A0)
midi_max_pitch = 108  # Highest MIDI note (C8)

def pitch_to_piano_roll(time, frequency, confidence, fs, confidence_threshold=0.5, window_size=5):
    # Filter out low-confidence predictions
    valid_indices = confidence > confidence_threshold
    time = time[valid_indices]
    frequency = frequency[valid_indices]
    
    # Handle the case where the filtered data is empty
    if len(time) == 0:
        print("No valid data after filtering by confidence threshold.")
        return np.zeros((midi_max_pitch - midi_min_pitch + 1, 1))  # Return an empty piano roll

    # Smooth the frequency values using a moving average filter
    smoothed_frequency = np.convolve(frequency, np.ones(window_size) / window_size, mode='same')

    # Convert smoothed frequency to MIDI note numbers
    midi_notes = np.round(69 + 12 * np.log2(smoothed_frequency / 440.0)).astype(int)
    
    # Clip notes to the valid MIDI range
    midi_notes = np.clip(midi_notes, midi_min_pitch, midi_max_pitch)
    
    # Create time bins
    duration = time.max()
    n_bins = int(np.ceil(duration * fs)) + 1  # Add 1 to ensure edge cases fit
    piano_roll = np.zeros((midi_max_pitch - midi_min_pitch + 1, n_bins))
    
    # Map MIDI notes to piano roll
    for t, note in zip(time, midi_notes):
        time_idx = int(np.floor(t * fs))
        note_idx = note - midi_min_pitch
        if time_idx < n_bins:  # Ensure the index is within bounds
            piano_roll[note_idx, time_idx] = 1  # Set note active
    
    return piano_roll


# Function to save piano roll as MIDI
def piano_roll_to_midi(piano_roll, fs, output_path):
    midi = pretty_midi.PrettyMIDI()
    piano = pretty_midi.Instrument(program=0)  # Acoustic Grand Piano
    
    for pitch, row in enumerate(piano_roll):
        note_on = None
        for time_idx, value in enumerate(row):
            if value > 0 and note_on is None:
                note_on = time_idx
            elif value == 0 and note_on is not None:
                start_time = note_on / fs
                end_time = time_idx / fs
                midi_note = pretty_midi.Note(
                    velocity=100,
                    pitch=pitch + midi_min_pitch,
                    start=start_time,
                    end=end_time
                )
                piano.notes.append(midi_note)
                note_on = None
        if note_on is not None:  # Handle note at the end
            start_time = note_on / fs
            end_time = len(row) / fs
            midi_note = pretty_midi.Note(
                velocity=100,
                pitch=pitch + midi_min_pitch,
                start=start_time,
                end=end_time
            )
            piano.notes.append(midi_note)
    
    midi.instruments.append(piano)
    midi.write(output_path)


# Main loop: Process HDF5 data and convert to piano roll
with h5py.File(h5_file_path, "r") as h5_file:
    for group_name in h5_file.keys():
        print(f"Processing group: {group_name}")
        time = h5_file[group_name]["time"][:]
        frequency = h5_file[group_name]["frequency"][:]
        confidence = h5_file[group_name]["confidence"][:]
        
        # Convert to piano roll
        piano_roll = pitch_to_piano_roll(time, frequency, confidence, fs)
        
        # Save piano roll as HDF5
        piano_roll_path = os.path.join(output_dir, f"{group_name}_piano_roll.h5")
        with h5py.File(piano_roll_path, "w") as piano_h5:
            piano_h5.create_dataset("piano_roll", data=piano_roll)
            print(f"Saved piano roll to: {piano_roll_path}")
        
        # Save as MIDI
        midi_path = os.path.join(output_dir, f"{group_name}.mid")
        piano_roll_to_midi(piano_roll, fs, midi_path)
        print(f"Saved MIDI file to: {midi_path}")
# Out:
# Processing group: BigTroubles_Phantom_STEM_04
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/BigTroubles_Phantom_STEM_04_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/BigTroubles_Phantom_STEM_04.mid
# Processing group: BrandonWebster_YesSirICanFly_STEM_02
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/BrandonWebster_YesSirICanFly_STEM_02_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/BrandonWebster_YesSirICanFly_STEM_02.mid
# Processing group: CelestialShore_DieForUs_STEM_01
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/CelestialShore_DieForUs_STEM_01_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/CelestialShore_DieForUs_STEM_01.mid
# Processing group: CelestialShore_DieForUs_STEM_02
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/CelestialShore_DieForUs_STEM_02_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/CelestialShore_DieForUs_STEM_02.mid
# Processing group: ClaraBerryAndWooldog_AirTraffic_STEM_08
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/ClaraBerryAndWooldog_AirTraffic_STEM_08_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/ClaraBerryAndWooldog_AirTraffic_STEM_08.mid
# Processing group: ClaraBerryAndWooldog_Stella_STEM_07
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/ClaraBerryAndWooldog_Stella_STEM_07_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/ClaraBerryAndWooldog_Stella_STEM_07.mid
# Processing group: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.mid
# Processing group: Creepoid_OldTree_STEM_07
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/Creepoid_OldTree_STEM_07_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/Creepoid_OldTree_STEM_07.mid
# Processing group: FacesOnFilm_WaitingForGa_STEM_03
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/FacesOnFilm_WaitingForGa_STEM_03_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/FacesOnFilm_WaitingForGa_STEM_03.mid
# Processing group: MusicDelta_80sRock_STEM_04
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_80sRock_STEM_04_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_80sRock_STEM_04.mid
# Processing group: MusicDelta_Beatles_STEM_08
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Beatles_STEM_08_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Beatles_STEM_08.mid
# Processing group: MusicDelta_Britpop_STEM_07
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Britpop_STEM_07_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Britpop_STEM_07.mid
# Processing group: MusicDelta_Britpop_STEM_08
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Britpop_STEM_08_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Britpop_STEM_08.mid
# Processing group: MusicDelta_Country1_STEM_05
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Country1_STEM_05_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Country1_STEM_05.mid
# Processing group: MusicDelta_Country2_STEM_05
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Country2_STEM_05_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Country2_STEM_05.mid
# Processing group: MusicDelta_Disco_STEM_04
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Disco_STEM_04_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Disco_STEM_04.mid
# Processing group: MusicDelta_Gospel_STEM_06
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Gospel_STEM_06_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Gospel_STEM_06.mid
# Processing group: MusicDelta_Reggae_STEM_04
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Reggae_STEM_04_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/MusicDelta_Reggae_STEM_04.mid
# Processing group: NightPanther_Fire_STEM_07
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/NightPanther_Fire_STEM_07_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/NightPanther_Fire_STEM_07.mid
# Processing group: PortStWillow_StayEven_STEM_08
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/PortStWillow_StayEven_STEM_08_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/PortStWillow_StayEven_STEM_08.mid
# Processing group: SecretMountains_HighHorse_STEM_09
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/SecretMountains_HighHorse_STEM_09_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/SecretMountains_HighHorse_STEM_09.mid
# Processing group: StrandOfOaks_Spacestation_STEM_04
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/StrandOfOaks_Spacestation_STEM_04_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/StrandOfOaks_Spacestation_STEM_04.mid
# Processing group: TheScarletBrand_LesFleursDuMal_STEM_08
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/TheScarletBrand_LesFleursDuMal_STEM_08_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/TheScarletBrand_LesFleursDuMal_STEM_08.mid
# Processing group: TheSoSoGlos_Emergency_STEM_05
# Saved piano roll to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/TheSoSoGlos_Emergency_STEM_05_piano_roll.h5
# Saved MIDI file to: /Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/TheSoSoGlos_Emergency_STEM_05.mid

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

def visualize_piano_roll(piano_roll_input, fs, midi_min_pitch=21, midi_max_pitch=108):
    """
    Visualize a piano roll matrix or load it from an HDF5 file.

    Parameters:
    - piano_roll_input: Either a 2D numpy array (piano roll) or a file path (HDF5).
    - fs: Sampling frequency (time bins per second).
    - midi_min_pitch: Lowest MIDI pitch in the piano roll.
    - midi_max_pitch: Highest MIDI pitch in the piano roll.
    """
    # Check if the input is a file path
    if isinstance(piano_roll_input, str):  # If it's a string, assume it's a file path
        with h5py.File(piano_roll_input, "r") as h5_file:
            piano_roll = h5_file["piano_roll"][:]  # Load the piano roll dataset
    else:
        piano_roll = piano_roll_input  # Otherwise, assume it's already a numpy array

    # Generate time and pitch labels
    num_time_bins = piano_roll.shape[1]
    time = np.arange(num_time_bins) / fs
    midi_pitches = np.arange(midi_min_pitch, midi_max_pitch + 1)
    
    # Plot piano roll
    plt.figure(figsize=(12, 6))
    plt.imshow(
        piano_roll, 
        aspect='auto', 
        origin='lower', 
        cmap='binary', 
        extent=[time[0], time[-1], midi_pitches[0], midi_pitches[-1]]
    )
    plt.colorbar(label="Activation")
    plt.xlabel("Time (s)")
    plt.ylabel("MIDI Pitch")
    plt.title("Piano Roll")
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# #### test with one audio track

# %%
piano_roll_path = '/Volumes/T7/mini_MedleyDB_pitch/piano_rolls_crepe/BigTroubles_Phantom_STEM_04_piano_roll.h5'
visualize_piano_roll(piano_roll_path, fs, midi_min_pitch=21, midi_max_pitch=108)

# %% [markdown]
# ## PYin

# %%
pip install essentia
# Out:
# Requirement already satisfied: essentia in /Users/mona/anaconda3/envs/mir-final/lib/python3.8/site-packages (2.1b6.dev1177)
# Requirement already satisfied: numpy>=1.8.2 in /Users/mona/anaconda3/envs/mir-final/lib/python3.8/site-packages (from essentia) (1.24.3)
# Requirement already satisfied: six in /Users/mona/anaconda3/envs/mir-final/lib/python3.8/site-packages (from essentia) (1.16.0)
# Requirement already satisfied: pyyaml in /Users/mona/anaconda3/envs/mir-final/lib/python3.8/site-packages (from essentia) (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import librosa
import numpy as np
from tqdm import tqdm

# Load directory containing audio files
audio_dir = "/Volumes/T7/mini_MedleyDB_pitch/audio"
output_dir = "/Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin"
os.makedirs(output_dir, exist_ok=True)  # Create output directory if it doesn't exist

# Helper function to extract pitch using PYin
def extract_pitch_pyin(audio, sr):
    """
    Extract pitch using Librosa's PYin algorithm.
    """
    pitches, voiced_flags, voiced_probs = librosa.pyin(
        audio,
        fmin=librosa.note_to_hz('C2'),  # Minimum pitch (C2 ~ 65.41 Hz)
        fmax=librosa.note_to_hz('C7'),  # Maximum pitch (C7 ~ 2093 Hz)
        sr=sr,
        fill_na=0.0  # Replace unvoiced frames with 0.0
    )
    # Generate time array for the pitch values
    times = librosa.times_like(pitches, sr=sr)
    return times, pitches, voiced_probs

# Get list of valid audio files (filter out hidden files)
audio_files = [
    os.path.join(audio_dir, f)
    for f in os.listdir(audio_dir)
    if f.endswith('.wav') and not f.startswith('._')
]

# Process audio files
for audio_path in tqdm(audio_files, desc="Processing audio files"):
    try:
        print(f"Processing: {audio_path}")
        
        # Load audio
        audio, sr = librosa.load(audio_path, sr=16000, mono=True)

        # Run pitch detection using PYin
        time, frequency, confidence = extract_pitch_pyin(audio, sr)

        # Handle cases where PYin returns NaN for unvoiced sections
        frequency = np.nan_to_num(frequency, nan=0.0)
        confidence = np.nan_to_num(confidence, nan=0.0)

        # Save results to .npy files
        base_name = os.path.splitext(os.path.basename(audio_path))[0]
        np.save(os.path.join(output_dir, f"{base_name}_time.npy"), time)
        np.save(os.path.join(output_dir, f"{base_name}_frequency.npy"), frequency)
        np.save(os.path.join(output_dir, f"{base_name}_confidence.npy"), confidence)

        print(f"Saved pitch data for {audio_path} to {output_dir}")

    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
# Out:
# Processing audio files:   0%|          | 0/24 [00:00<?, ?it/s]
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/BigTroubles_Phantom_STEM_04.wav
# Processing audio files:   4%|▍         | 1/24 [00:26<10:07, 26.40s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/BigTroubles_Phantom_STEM_04.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Britpop_STEM_08.wav
# Processing audio files:   8%|▊         | 2/24 [00:33<05:26, 14.84s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Britpop_STEM_08.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_Stella_STEM_07.wav
# Processing audio files:  12%|█▎        | 3/24 [01:08<08:28, 24.24s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_Stella_STEM_07.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/PortStWillow_StayEven_STEM_08.wav
# Processing audio files:  17%|█▋        | 4/24 [02:00<11:45, 35.27s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/PortStWillow_StayEven_STEM_08.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_80sRock_STEM_04.wav
# Processing audio files:  21%|██        | 5/24 [02:07<07:53, 24.91s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_80sRock_STEM_04.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/StrandOfOaks_Spacestation_STEM_04.wav
# Processing audio files:  25%|██▌       | 6/24 [02:49<09:15, 30.85s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/StrandOfOaks_Spacestation_STEM_04.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/TheScarletBrand_LesFleursDuMal_STEM_08.wav
# Processing audio files:  29%|██▉       | 7/24 [03:40<10:33, 37.25s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/TheScarletBrand_LesFleursDuMal_STEM_08.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.wav
# Processing audio files:  33%|███▎      | 8/24 [04:09<09:15, 34.73s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/Creepoid_OldTree_STEM_07.wav
# Processing audio files:  38%|███▊      | 9/24 [05:00<09:58, 39.87s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/Creepoid_OldTree_STEM_07.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_AirTraffic_STEM_08.wav
# Processing audio files:  42%|████▏     | 10/24 [05:27<08:21, 35.83s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/ClaraBerryAndWooldog_AirTraffic_STEM_08.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/CelestialShore_DieForUs_STEM_02.wav
# Processing audio files:  46%|████▌     | 11/24 [06:09<08:12, 37.86s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/CelestialShore_DieForUs_STEM_02.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/CelestialShore_DieForUs_STEM_01.wav
# Processing audio files:  50%|█████     | 12/24 [06:52<07:50, 39.19s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/CelestialShore_DieForUs_STEM_01.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/SecretMountains_HighHorse_STEM_09.wav
# Processing audio files:  54%|█████▍    | 13/24 [07:44<07:54, 43.09s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/SecretMountains_HighHorse_STEM_09.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Disco_STEM_04.wav
# Processing audio files:  58%|█████▊    | 14/24 [08:03<05:58, 35.85s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Disco_STEM_04.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Beatles_STEM_08.wav
# Processing audio files:  62%|██████▎   | 15/24 [08:08<03:59, 26.63s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Beatles_STEM_08.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Gospel_STEM_06.wav
# Processing audio files:  67%|██████▋   | 16/24 [08:20<02:57, 22.16s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Gospel_STEM_06.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Country1_STEM_05.wav
# Processing audio files:  71%|███████   | 17/24 [08:25<01:59, 17.07s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Country1_STEM_05.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Country2_STEM_05.wav
# Processing audio files:  75%|███████▌  | 18/24 [08:28<01:16, 12.73s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Country2_STEM_05.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/BrandonWebster_YesSirICanFly_STEM_02.wav
# Processing audio files:  79%|███████▉  | 19/24 [08:43<01:07, 13.47s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/BrandonWebster_YesSirICanFly_STEM_02.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Reggae_STEM_04.wav
# Processing audio files:  83%|████████▎ | 20/24 [08:46<00:41, 10.33s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Reggae_STEM_04.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/FacesOnFilm_WaitingForGa_STEM_03.wav
# Processing audio files:  88%|████████▊ | 21/24 [09:25<00:56, 18.94s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/FacesOnFilm_WaitingForGa_STEM_03.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Britpop_STEM_07.wav
# Processing audio files:  92%|█████████▏| 22/24 [09:31<00:30, 15.01s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/MusicDelta_Britpop_STEM_07.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/TheSoSoGlos_Emergency_STEM_05.wav
# Processing audio files:  96%|█████████▌| 23/24 [09:56<00:18, 18.10s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/TheSoSoGlos_Emergency_STEM_05.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin
# Processing: /Volumes/T7/mini_MedleyDB_pitch/audio/NightPanther_Fire_STEM_07.wav
# Processing audio files: 100%|██████████| 24/24 [10:27<00:00, 26.15s/it]
# Saved pitch data for /Volumes/T7/mini_MedleyDB_pitch/audio/NightPanther_Fire_STEM_07.wav to /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the saved data
base_name = "MusicDelta_Britpop_STEM_07"  # Replace with your audio file's base name
output_dir = "/Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin"
time = np.load(os.path.join(output_dir, f"{base_name}_time.npy"))
frequency = np.load(os.path.join(output_dir, f"{base_name}_frequency.npy"))
confidence = np.load(os.path.join(output_dir, f"{base_name}_confidence.npy"))

# Plot the pitch contour
plt.figure(figsize=(12, 6))
plt.plot(time, frequency, label="Pitch (Hz)", linewidth=1.5, color="blue")
plt.scatter(time, frequency, c=confidence, cmap="viridis", s=10, label="Confidence")
plt.colorbar(label="Confidence")
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title(f"Pitch Contour for {base_name}")
plt.legend()
plt.grid()
plt.show()

# %%
import os
import numpy as np

# Parameters for piano roll
output_dir = "/Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin"
fs = 100  # Sampling frequency (100 frames per second)
midi_min_pitch = 21  # Lowest MIDI note (A0)
midi_max_pitch = 108  # Highest MIDI note (C8)
confidence_threshold = 0.5  # Minimum confidence to include a note

# Function to convert frequency to MIDI note number
def frequency_to_midi(frequency):
    """
    Convert frequency (Hz) to MIDI note number.
    """
    return 69 + 12 * np.log2(frequency / 440.0)

# Function to create a piano roll from pitch data
def create_piano_roll(time, frequency, confidence, fs, confidence_threshold=0.5):
    """
    Map pitch data to a piano roll representation.
    """
    # Filter out low-confidence predictions
    valid_indices = confidence > confidence_threshold
    time = time[valid_indices]
    frequency = frequency[valid_indices]
    
    # Convert frequency to MIDI notes
    midi_notes = frequency_to_midi(frequency)
    midi_notes = np.round(midi_notes).astype(int)
    
    # Clip MIDI notes to valid range
    midi_notes = np.clip(midi_notes, midi_min_pitch, midi_max_pitch)
    
    # Create time bins
    duration = time.max()
    n_bins = int(np.ceil(duration * fs)) + 1
    piano_roll = np.zeros((midi_max_pitch - midi_min_pitch + 1, n_bins))
    
    # Map MIDI notes to the piano roll
    for t, note in zip(time, midi_notes):
        time_idx = int(np.floor(t * fs))
        note_idx = note - midi_min_pitch
        if time_idx < n_bins:  # Ensure the index is within bounds
            piano_roll[note_idx, time_idx] = 1
    
    return piano_roll

# Specify the file to process
base_name = "MusicDelta_Britpop_STEM_07"  # Replace with the desired audio file's base name
time = np.load(os.path.join(output_dir, f"{base_name}_time.npy"))
frequency = np.load(os.path.join(output_dir, f"{base_name}_frequency.npy"))
confidence = np.load(os.path.join(output_dir, f"{base_name}_confidence.npy"))

# Create the piano roll
piano_roll = create_piano_roll(time, frequency, confidence, fs, confidence_threshold)

# Save the piano roll for further use
piano_roll_output_path = os.path.join(output_dir, f"{base_name}_piano_roll.npy")
np.save(piano_roll_output_path, piano_roll)
print(f"Piano roll saved to: {piano_roll_output_path}")

# Optional: Visualize the piano roll
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.imshow(
    piano_roll,
    aspect="auto",
    origin="lower",
    cmap="binary",
    extent=[0, piano_roll.shape[1] / fs, midi_min_pitch, midi_max_pitch]
)
plt.colorbar(label="Activation")
plt.xlabel("Time (s)")
plt.ylabel("MIDI Pitch")
plt.title(f"Piano Roll for {base_name}")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()
# Out:
# Piano roll saved to: /Volumes/T7/mini_MedleyDB_pitch/processed_pitch_PYin/MusicDelta_Britpop_STEM_07_piano_roll.npy
